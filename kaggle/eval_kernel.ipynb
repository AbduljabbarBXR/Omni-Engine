# %%
# !git clone https://github.com/AbduljabbarBXR/Omni-Engine.git

# %%
# %cd /kaggle/working/Omni-Engine

# %%
# !pip uninstall -y -q torchvision torchaudio 2>/dev/null || true!pip install -q "numpy<2" "torch==2.2.2" "transformers==4.44.2" --extra-index-url https://download.pytorch.org/whl/cu118import torchprint('CUDA:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU')

# %%
import subprocess, sysimport osos.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'for name in ['flat', 'graph', 'hebbian']:    p = subprocess.run([sys.executable, '-m', 'omni.eval', '--run', f'/kaggle/input/omni-checkpoints/{name}', '--blocks', '100'], capture_output=True, text=True)    print(f'==== {name} ====')    print(p.stdout[-3000:])    if p.returncode != 0:        print(p.stderr[-1500:])print('EVAL_DONE')
